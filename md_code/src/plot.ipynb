# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import matplotlib 
import os
import sys

# %%
path = '../output/Zundel-100.xyz'

fh = np.genfromtxt(path)
x = fh[:,0]
y = fh[:,1]
print x
print y

plt.scatter(x,y)
plt.xlabel('Bond length difference')
plt.ylabel('Cosine $\theta$')
plt.savefig('../plots/Zundle-100.png')
plt.show()
# Out:
# [-0.45355362 -0.44631621 -0.43926829 ..., -0.38851479 -0.38627848
#  -0.38614833]
# [ 0.00305116  0.01273465  0.02223432 ..., -0.02296734 -0.03230858
#  -0.04158819]

# %%
# !jupyter nbconvert --to script 'plot.ipynb' #--stdout
# Out:
# [NbConvertApp] Converting notebook plot.ipynb to script
#
# # coding: utf-8
#
# # In[10]:
#
# get_ipython().magic(u'matplotlib inline')
# import numpy as np
# from matplotlib import pyplot as plt
# import matplotlib
# import os
# import sys
#
#
# # In[11]:
#
# path = '../output/Zundel-100.xyz'
#
# fh = np.genfromtxt(path)
# x = fh[:,0]
# y = fh[:,1]
# print x
# print y
#
# plt.scatter(x,y)
# plt.xlabel('Bond length difference')
# plt.ylabel('Cosine $\theta$')
# plt.savefig('../plots/Zundle-100.png')
# plt.show()
#
#
# # In[12]:
#
# ipython nbconvert --to script plots.py --stdout
#
#
# # In[14]:
#
# get_ipython().system(u"jupyter nbconvert --to script 'plot.ipynb'")
#
#
# # In[ ]:

# %%
# !ls
# Out:
# dotproductvsbondlength.f90	   inversioneigenrevisited.f90	plot.py
# inversionbondlengthdifference.f90  plot.ipynb			timeseries.f90
